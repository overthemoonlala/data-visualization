# %% [markdown]
# <a href="https://colab.research.google.com/github/overthemoonlala/data-visualization/blob/main/%EC%8A%A4%ED%83%80%EB%B2%85%EC%8A%A4%EB%8A%94_%EB%AA%87%EA%B0%9C%EA%B0%80_%EC%9E%88%EC%9D%84%EA%B9%8C%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 전국 카페 데이터
# - 데이터 불러오기
# - 데이터 전처리
# - 전국과 서울, 블랜드 별 데이터 분석 결과 도출
# - 시각화

# %% [markdown]
# # 데이터 분석방법론
# - 1단계: 분석기획(비지니스 이해 및 범위 설정)
# - 2단계: 데이터 준비(데이터 수집)
# - 3단계: 데이터분석(모델링)
# - 4단계: 시스템 구현(설계, 구현)
# - 5단계: 평가 및 전개(모델 발전 계획 수립)

# %% [markdown]
# # 데이터 분석 기법의 이해
# - 데이터웨어하우나 데이터마트를 통해 분석데이터 구성
# - 시각화 기법
# - 탐색적 자료분석(EDA)
# - 통계분석
# - 데이터 마이닝

# %% [markdown]
# # 공공데이터를 이용한 카페 상권 분석

# %%
# 라이브러리 불러오기!!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 데이터 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/소상공인시장진흥공단_상가(상권)정보_20230930/소상공인시장진흥공단_상가(상권)정보_경기_202309.csv',
                 sep = ',',
                 encoding = 'utf-8')
# Out:
# <ipython-input-39-44c8078a9f16>:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/소상공인시장진흥공단_상가(상권)정보_20230930/소상공인시장진흥공단_상가(상권)정보_경기_202309.csv',

# %%
# 데이터 기본 정보 확인
df.head()
# Out:
#                  상가업소번호               상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0  MA0101202210A0082752             엠마스키친  NaN        I2       음식      I204
# 1  MA0101202210A0004063           팽성농산물센터  NaN        G2       소매      G205
# 2  MA0101202210A0089792      역전할머니맥주평택궁리점  NaN        I2       음식      I211
# 3  MA0101202210A0101847  지제역부동산마트공인중개사사무소  NaN        L1      부동산      L102
# 4  MA0101202210A0050965          혜윰건축사사무소  NaN        M1    과학·기술      M109
#
#   상권업종중분류명 상권업종소분류코드         상권업종소분류명 표준산업분류코드  ...  \
# 0      서양식    I20401              경양식   I56123  ...
# 1   식료품 소매    G20506        채소/과일 소매업   G47215  ...
# 2       주점    I21103           생맥주 전문   I56213  ...
# 3  부동산 서비스    L10203       부동산 중개/대리업   L68221  ...
# 4   기술 서비스    M10901  건축 설계 및 관련 서비스업   M72111  ...
#
#                       건물관리번호    건물명                  도로명주소   구우편번호  신우편번호  \
# 0  4146510600105160003000002    NaN   경기도 용인시 수지구 성복2로 270  448831  16806
# ...

# %%
# 데이터 기본 정보 확인
df.tail()
# Out:
#                       상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 560031  MA0101202307A0000094       스타커피  NaN        I2       음식      I212
# 560032  MA0101202307A0000097         뮤픽  NaN        N1  시설관리·임대      N110
# 560033  MA0101202307A0000965    비비드스튜디오  NaN        M1    과학·기술      M112
# 560034  MA0101202307A0005994         정원  NaN        I2       음식      I201
# 560035  MA0101202307A0061737  본가부대찌개삼겹살  NaN        I2       음식      I201
#
#        상권업종중분류명 상권업종소분류코드        상권업종소분류명 표준산업분류코드  ...  \
# 560031    비알코올     I21201              카페   I56221  ...
# 560032  가정용품 대여    N11099  기타 개인/가정용품 대여업   N76299  ...
# 560033   전문 디자인    M11203         시각 디자인업   M73203  ...
# 560034       한식    I20101          백반/한정식   I56111  ...
# 560035       한식    I20107       돼지고기 구이/찜   I56111  ...
#
#                            건물관리번호    건물명                     도로명주소   구우편번호  \
# 560031  4182033027101100001009135    NaN       경기도 가평군 상면 비룡로 1953  477823
# ...

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560036 entries, 0 to 560035
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     560036 non-null  object
#  1   상호명        560036 non-null  object
#  2   지점명        8773 non-null    object
#  3   상권업종대분류코드  560036 non-null  object
#  4   상권업종대분류명   560036 non-null  object
#  5   상권업종중분류코드  560036 non-null  object
#  6   상권업종중분류명   560036 non-null  object
#  7   상권업종소분류코드  560036 non-null  object
#  8   상권업종소분류명   560036 non-null  object
#  9   표준산업분류코드   559967 non-null  object
#  10  표준산업분류명    559967 non-null  object
#  11  시도코드       560036 non-null  int64
#  12  시도명        560036 non-null  object
#  13  시군구코드      560036 non-null  int64
#  14  시군구명       560036 non-null  object
#  15  행정동코드      560036 non-null  int64
#  16  행정동명       560036 non-null  object
#  17  법정동코드      560036 non-null  int64
#  18  법정동명       560036 non-null  object
# ...

# %%
df.상권업종소분류코드.unique()
# Out:
# array(['I20401', 'G20506', 'I21103', 'L10203', 'M10901', 'I20112',
#        'I21201', 'I20101', 'M11203', 'I21104', 'I20301', 'I21006',
#        'I20105', 'M10903', 'N10802', 'G21301', 'P10603', 'G20905',
#        'I21101', 'N10501', 'I20104', 'I21008', 'R10407', 'M10501',
#        'R10311', 'S20301', 'G20404', 'I21007', 'G21304', 'M11301',
#        'I21001', 'G21701', 'R10310', 'G21503', 'I10103', 'R10406',
#        'G20902', 'N10201', 'S20703', 'S20802', 'N10202', 'I20107',
#        'S20601', 'S20701', 'S20803', 'I21003', 'M10703', 'S20302',
#        'G20405', 'Q10204', 'S20702', 'I20202', 'P10613', 'G21001',
#        'G20509', 'G20503', 'I20103', 'I20102', 'I10201', 'S20901',
#        'N11004', 'G20907', 'G21401', 'G20911', 'G21502', 'R10499',
#        'G21601', 'M11201', 'G21501', 'N10805', 'M10303', 'N10401',
#        'I20701', 'M10402', 'G21002', 'P10607', 'G20803', 'N10402',
#        'M10599', 'P10629', 'N10901', 'N10599', 'I20109', 'G22201',
# ...

# %% [markdown]
# # 필요한 컬럼만 빼오기

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df=df[['상호명','지점명','상권업종대분류명','상권업종중분류명','시도명','시군구명','행정동명']]

# %%
df.head()
# Out:
#                 상호명  지점명 상권업종대분류명 상권업종중분류명  시도명     시군구명 행정동명
# 0             엠마스키친  NaN       음식      서양식  경기도  용인시 수지구  성복동
# 1           팽성농산물센터  NaN       소매   식료품 소매  경기도      평택시  팽성읍
# 2      역전할머니맥주평택궁리점  NaN       음식       주점  경기도      평택시  고덕면
# 3  지제역부동산마트공인중개사사무소  NaN      부동산  부동산 서비스  경기도      평택시  동삭동
# 4          혜윰건축사사무소  NaN    과학·기술   기술 서비스  경기도  안산시 상록구   일동

# %%
# 지점명 null 값 엄청 많음!!!
df.isnull().sum()
# Out:
# 상호명              0
# 지점명         551263
# 상권업종대분류명         0
# 상권업종중분류명         0
# 시도명              0
# 시군구명             0
# 행정동명             0
# dtype: int64

# %%
# 데이터 요약을 위한 describe() 매세드!!
# 통계량 출력해줌당
df.describe()
# Out:
#            상호명   지점명 상권업종대분류명 상권업종중분류명     시도명    시군구명    행정동명
# count   560036  8773   560036   560036  560036  560036  560036
# unique  420825   665       10       75       1      42     539
# top      컴퓨터수리   코리아       음식       한식     경기도     화성시     중앙동
# freq       471   349   173916    68796  560036   33697   11486

# %%
# set 자료형은 순서가 없기 때문에 인덱싱으로 값을 얻을 수 없다.
set(df['상권업종중분류명'])
# Out:
# {'가구 소매',
#  '가전·통신 소매',
#  '가전제품 수리',
#  '가정용품 대여',
#  '고용 알선',
#  '광고',
#  '교육 지원',
#  '구내식당·뷔페',
#  '기술 서비스',
#  '기타 가정용품 수리',
#  '기타 간이',
#  '기타 개인',
#  '기타 교육',
#  '기타 보건',
#  '기타 사업 서비스',
#  '기타 상품 소매',
#  '기타 생활용품 소매',
#  '기타 숙박',
#  '기타 외국',
#  '기타 전문 과학',
#  '담배 소매',
#  '도서관·사적지',
#  '동남아시아',
#  '모터사이클 소매',
#  '모터사이클 수리',
#  '법무관련 ',
#  '병원',
#  '본사·경영 컨설팅',
#  '부동산 서비스',
#  '비알코올 ',
#  '사무 지원',
#  '사진 촬영',
#  '산업용품 대여',
#  '서양식',
#  '섬유·의복·신발 소매',
#  '세탁',
#  '수의',
#  '스포츠 서비스',
#  '시계·귀금속 소매',
#  '시설관리',
#  '시장 조사',
#  '식료품 소매',
#  '식물 소매',
#  '안경·정밀기기 소매',
#  '애완동물·용품 소매',
#  '여행사·보조',
#  '연료 소매',
#  '오락용품 소매',
#  '욕탕·신체관리',
#  '운송장비 대여',
#  '유원지·오락',
#  '음료 소매',
#  '의약·화장품 소매',
#  '의원',
#  '이용·미용',
#  '인쇄·제품제작',
#  '일반 교육',
#  '일반 숙박',
#  '일식',
#  '자동차 부품 소매',
#  '자동차 수리·세차',
#  '장례식장 ',
#  '장식품 소매',
#  '전문 디자인',
#  '조경·유지',
#  '종합 소매',
#  '주점',
#  '중고 상품 소매',
#  '중식',
#  '철물·건설자재 소매',
#  '청소·방제',
#  '컴퓨터 수리',
#  '통신장비 수리',
#  '한식',
#  '회계·세무'}

# %%
# 카페만 뽑아내보자!!!
# 상표명중 카페가 들어가진 것 뽑기
# 그 중에서 스타벅스가 들어가진 것 뽑기
# 4개만 출력 됐음 => 그럴리가 없는데??
# 해당 파일 데이터 쓸모 없는 것으로 판단/////
# 스타벅스 크롤링하여 나타내기로 결정!!!!
# 기각된 자료입니다

df_starbucks = df[df['상호명'].str.contains('스타벅스')] #df 조건식
df_starbucks.count()
# Out:
# 상호명         4
# 지점명         0
# 상권업종대분류명    4
# 상권업종중분류명    4
# 시도명         4
# 시군구명        4
# 행정동명        4
# dtype: int64

# %%
# 일반 카페 분류
df[df[]]
